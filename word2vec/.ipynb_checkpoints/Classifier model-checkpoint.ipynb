# %%
import pickle
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
import seaborn as sns
import numpy as np
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the table

# %%
with open('node_data.pkl','rb') as f:
    data = pickle.load(f)

# %%
data.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.402714  0.657317  0.335929 -0.256412 -0.552803  0.119585  0.400852
# 1  0.217110  0.160059  0.059069 -0.254024 -0.387055  0.226386 -0.048736
# 2 -0.350678  0.996265  0.180337 -0.115023 -0.225416  0.724037  0.372910
# 3 -0.030048  0.243647  0.303754 -0.190984 -0.493702 -0.378347  0.188431
# 4 -0.268967  0.395189 -0.011676 -0.259565 -0.435848 -0.436084 -0.086013
#
#           7         8         9  ...        42        43        44        45  \
# 0 -0.361223  0.165233  0.422753  ...  0.434321  0.509581  0.240941  0.106144
# 1 -0.496583 -0.128342 -0.419064  ... -0.027305  0.377318  0.495416  0.631945
# 2 -0.530221 -0.020369  0.373741  ... -0.112676  0.093522  0.235262  0.259993
# 3 -0.210383 -0.159610  0.196847  ... -0.246493 -0.237207  0.291114  0.088273
# 4 -0.049238 -0.484350 -0.208222  ... -0.085299  0.186761  0.424719  0.039756
#
#          46        47        48        49          Label  \
# 0 -0.235282  0.126130  0.370136  0.003918          local
# 1  0.033577 -0.064106 -0.305564 -0.139526  western-local
# 2  0.012765  0.139626  0.014529  0.173805  western-local
# 3  0.472295 -0.375174  0.710751  0.160327          local
# 4  0.163993 -0.269821 -0.563700  0.432406  western-local
#
#                         Restaurant
# 0       enjoy-eating-house-and-bar
# 1                           elemen
# 2       breko-cafe-holland-village
# 3                  thesaltedplumsg
# 4  four-seasons-durians-restaurant
#
# [5 rows x 52 columns]

# %%
# convert label to numbers
# 1 = western
# 2 = local food
# 3 = western-local/western-japanese/japanese-local/middle-eastern
# 4 = dessert
# 5 = japanese

data['Cuisine'] = data['Label']

data['Label'].replace(to_replace=['western','local','western-local','dessert',
                                    'japanese','western-japanese', 'japanese-local','thai','middle-eastern'],
                      value=[1,2,3,4,5,3,3,2,2], inplace=True)

# %%
# Select non-fusion food
# data = data[data['Label'] != 3]

X = data.drop('Label', axis=1) # For training / testing
Y = data['Label'] # Label for training / testing

X_pca = X.drop(['Restaurant','Cuisine'], axis=1) # For PCA visual
Y_pca = Y.replace(to_replace=[1,2,3,4,5], value=['red','blue','black','green','orange']) # Label for PCA vis

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_pca)
plt.scatter(X_pca[:,0], X_pca[:,1], c=Y_pca, alpha=0.5)

# %% [markdown]
# # Build the model

# %%
X_train_label, X_test_label, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# %%
X_labels = X_test_label.iloc[:,-2:].copy()

# %%
# Get data for the train/test sets
X_train = X_train_label.drop(["Restaurant","Cuisine"], axis=1)
X_test = X_test_label.drop(["Restaurant","Cuisine"], axis=1)

# Get restaurant labels for the train/test sets
X_train_label = X_train_label.iloc[:,-1]
X_test_label = X_test_label.iloc[:,-1]

# %%
gnb = GaussianNB()
model = gnb.fit(X_train, y_train)
y_pred = model.predict(X_test)

target_names = ['Western','Asian','Fusion','Dessert','Japanese']
print(classification_report(y_test, y_pred, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Western       0.66      0.81      0.73        48
#        Asian       0.88      0.92      0.90        48
#       Fusion       0.48      0.28      0.35        36
#      Dessert       0.88      0.88      0.88        25
#     Japanese       0.75      0.83      0.79        18
#
#     accuracy                           0.74       175
#    macro avg       0.73      0.74      0.73       175
# weighted avg       0.72      0.74      0.73       175
